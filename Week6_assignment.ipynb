# %% [markdown]
# **Question 1**

# %% [markdown]
# Create a class called Student with attributes name, age, and grades (a list of integers). Write a method average_grade that calculates and returns the average grade of the student. Create three Student objects and print their average grades.

# %%
class Student:
  def __init__(self, name, age, grades):
    self.name = name
    self.age = age
    self.grades = grades

  def average_grade(self):
      if len(self.grades) == 0:
        return 0
      else:
        return sum(self.grades) / len(self.grades)

# %%
student1 = Student("Simrik", 20, [90, 97, 99, 95, 98])
student2 = Student("Simran", 22, [99, 94, 93, 96, 91])
student3 = Student("Seher", 21, [89, 99, 97, 94, 90])

# %%
print(f"The average grade of {student1.name} is {student1.average_grade()}.")
print(f"The average grade of {student2.name} is {student2.average_grade()}.")
print(f"The average grade of {student3.name} is {student3.average_grade()}.")
# Out:
# The average grade of Simrik is 95.8.
# The average grade of Simran is 94.6.
# The average grade of Seher is 93.8.

# %% [markdown]
# **Question 2**

# %% [markdown]
# Create a class called Book with attributes title, author. Write a method short_title that returns the first 10 characters of the book's title. Create three Book objects and print their short titles.

# %%
class Book:
  def __init__(self, title, author):
    self.title = title
    self.author = author

  def short_title(self):
    return self.title[:10]

# %%
book1 = Book("Don't Lose Your Mind, Lose Your Weight", "Rujuta Diwekar")
book2 = Book("The Graham Effect", "Elle Kennedy")
book3 = Book("Crossed Checked", "Julia Connors")

# %%
print(f"Short title of the book {book1.title} is '{book1.short_title()}'.")
print(f"Short title of the book {book2.title} is '{book2.short_title()}'.")
print(f"Short title of the book {book3.title} is '{book3.short_title()}'.")
# Out:
# Short title of the book Don't Lose Your Mind, Lose Your Weight is 'Don't Lose'.
# Short title of the book The Graham Effect is 'The Graham'.
# Short title of the book Crossed Checked is 'Crossed Ch'.

# %% [markdown]
# **Question 3**

# %% [markdown]
# Create a class called StudentResult with attributes name, age, and average_grade and include a method has_passed that returns True if the student's average grade is 50 or higher, and False otherwise . Create three Student objects and print the names of the students who have passed.

# %%
class StudentResult:
  def __init__(self, name, age, average_grade):
    self.name = name
    self.age = age
    self.average_grade = average_grade

  def has_passed(self):
    if self.average_grade >= 50:
      return True
    else:
      return False

# %%
student1 = StudentResult("Yarik", 21, 89)
student2 = StudentResult("Mangena", 20, 96)
student3 = StudentResult("Namyang", 22, 48)

# %%
print("Students who have passed the exam: ")
for student in [student1, student2, student3]:
    if student.has_passed():
        print(student.name)
# Out:
# Students who have passed the exam:
# Yarik
# Mangena

# %% [markdown]
# **Question 4**

# %% [markdown]
# Create a class called ShoppingCart with a list attribute items (each item is a dictionary with keys name and price). Write a method total_price that calculates and returns the total price of all items in the cart. Create a ShoppingCart object, add five items to it, and print the total price.

# %%
class ShoppingCart:
  def __init__(self):
    self.items = []

  def add_item(self, name, price):
    self.items.append({"name": name, "price": price})

  def total_price(self):
    return sum(item["price"] for item in self.items)
cart = ShoppingCart()

# %%
cart.add_item("Shortbread", 500)
cart.add_item("Walker Crisps", 300)
cart.add_item("Cheese", 640)
cart.add_item("Tulip", 360)
cart.add_item("Butter", 430)

# %%
print(f"The total price of the items in the cart: Rs.{cart.total_price()}.")
# Out:
# The total price of the items in the cart: Rs.2230.

# %% [markdown]
# **Question 5**

# %% [markdown]
# Create a class called TextAnalyzer with a string attribute text. Write a method word_count that returns the number of words in the text.Create a TextAnalyzer object with a sample text and print the word count

# %%
class TextAnalyzer:
  def __init__(self, text):
    self.text = text

  def word_count(self):
    words = self.text.split()
    return len(words)

# %%
text_1 = "Hello poeple of the world, this is Ningsamma Thebe Limbu."
analyzer = TextAnalyzer(text_1)

# %%
print(f"The word count is: {analyzer.word_count()}")
# Out:
# The word count is: 10

# %% [markdown]
# **Question 6**

# %% [markdown]
# Create a class called Playlist with a list attribute songs (each song is a dictionary with keys title and artist). Write a method shuffle that randomly shuffles the songs in the playlist. Create a Playlist object, add five songs to it, shuffle the playlist, and print the shuffled list of songs.

# %%
import random

class Playlist:
    def __init__(self):
      self.songs = []

    def add_song(self, title, artist):
      self.songs.append({"title of the song": title, "name of the artist": artist})

    def shuffle(self):
      random.shuffle(self.songs)

playlist = Playlist()

# %%
playlist.add_song("Nihita", "John Chamling Rai")
playlist.add_song("How Deep is Your Love", "Bee Gee")
playlist.add_song("Timi Nai Hau", "Sabin Rai")
playlist.add_song("Vanna Aaudaina", "Naren Limbu")
playlist.add_song("A Love Letter to Darjeeling", "Purna Rai")

# %%
playlist.shuffle()

# %%
print("Shuffled Playlist: ")
for song in playlist.songs:
    print(f"Title of the song: {song['title of the song']}, Artist: {song['name of the artist']}")
# Out:
# Shuffled Playlist:
# Title of the song: A Love Letter to Darjeeling, Artist: Purna Rai
# Title of the song: Vanna Aaudaina, Artist: Naren Limbu
# Title of the song: Nihita, Artist: John Chamling Rai
# Title of the song: How Deep is Your Love, Artist: Bee Gee
# Title of the song: Timi Nai Hau, Artist: Sabin Rai
